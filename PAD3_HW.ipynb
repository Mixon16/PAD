# %% [markdown]
# Zadanie 1

# %%
import pandas as pd

# %%
PATH = './drive/MyDrive'
hw = pd.read_csv(f'{PATH}/PAD_03_PD.csv', sep = ';')
hw
# Out:
#       ID Country  owns_car  owns_TV  owns_house  owns_Phone gender  Age
# 0      1       A       0.0      0.0         0.0           1      M   61
# 1      2       B       0.0      0.0         0.0           1      M   44
# 2      3       A       0.0      0.0         0.0           1      M   56
# 3      4       A       0.0      0.0         0.0           1      M   53
# 4      5       C       1.0      1.0         0.0           1      K   60
# ..   ...     ...       ...      ...         ...         ...    ...  ...
# 795  796       B       0.0      0.0         0.0           1      K   28
# 796  797       B       0.0      0.0         0.0           1      M   26
# 797  798       A       0.0      0.0         0.0           1      M   61
# 798  799       B       0.0      1.0         0.0           1      K   47
# 799  800       B       0.0      1.0         0.0           1      K   51
#
# [800 rows x 8 columns]

# %%
hw.dropna(inplace=True)
hw.groupby('Country').count()
# Out:
#           ID  owns_car  owns_TV  owns_house  owns_Phone  gender  Age
# Country
# A        323       323      323         323         323     323  323
# B        196       196      196         196         196     196  196
# C        181       181      181         181         181     181  181
# D         78        78       78          78          78      78   78

# %% [markdown]
# Zadanie 2

# %%
hw['owned_goods'] = hw.owns_car + hw.owns_TV + hw.owns_house + hw.owns_Phone
hw
# Out:
#       ID Country  owns_car  owns_TV  owns_house  owns_Phone gender  Age  \
# 0      1       A       0.0      0.0         0.0           1      M   61
# 1      2       B       0.0      0.0         0.0           1      M   44
# 2      3       A       0.0      0.0         0.0           1      M   56
# 3      4       A       0.0      0.0         0.0           1      M   53
# 4      5       C       1.0      1.0         0.0           1      K   60
# ..   ...     ...       ...      ...         ...         ...    ...  ...
# 795  796       B       0.0      0.0         0.0           1      K   28
# 796  797       B       0.0      0.0         0.0           1      M   26
# 797  798       A       0.0      0.0         0.0           1      M   61
# 798  799       B       0.0      1.0         0.0           1      K   47
# 799  800       B       0.0      1.0         0.0           1      K   51
#
#      owned_goods
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# ...

# %% [markdown]
# Zadanie 3

# %%
hw.groupby('gender').mean().owned_goods.round(2)
# Out:
# gender
# K    2.80
# M    0.89
# Name: owned_goods, dtype: float64

# %% [markdown]
# Zadanie 4

# %%
meanOwnedByCountry = hw.groupby('Country').mean().owned_goods.reset_index()
minAge = hw.groupby('Country').min().Age.reset_index()
result = pd.merge(meanOwnedByCountry, minAge, how='outer', on='Country')
result
# Out:
#   Country  owned_goods  Age
# 0       A     0.860681   18
# 1       B     1.459184   18
# 2       C     3.027624   18
# 3       D     4.000000   18
